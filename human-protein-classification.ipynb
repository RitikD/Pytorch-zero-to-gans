# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jovian-pytorch-z2g/submission.csv
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train.csv
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7353.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3660.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12737.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16495.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17803.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4302.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13070.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9903.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18162.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16257.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1107.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/498.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3268.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7096.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22007.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26702.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9075.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9551.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10200.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/807.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25270.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29995.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19499.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27496.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2640.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6882.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30913.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13386.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3054.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25926.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/351.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16548.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23324.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5023.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7391.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1392.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28399.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4834.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17674.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17693.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15156.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6958.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28167.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14453.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18548.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/52.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17811.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12868.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30522.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20320.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9278.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14727.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8804.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4425.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19739.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25028.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1681.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6797.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2239.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28917.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30033.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17850.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20994.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3508.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27641.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16215.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1111.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29026.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11222.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28763.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30202.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6531.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15864.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9005.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26779.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20046.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28425.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11194.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20031.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16078.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22705.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28518.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25230.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20232.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/866.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30504.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23626.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1965.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6869.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19626.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17521.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24911.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5922.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11807.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8935.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25337.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20692.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1777.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23218.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15960.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1557.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13823.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17330.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20866.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2015.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21333.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/180.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15551.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5156.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1442.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25600.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17826.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29270.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20806.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28777.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14979.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29554.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25370.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17295.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8032.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2173.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26466.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17744.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30674.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17958.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30608.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23159.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7512.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11154.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25378.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23694.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17923.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24472.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4568.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23303.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13683.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5798.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8748.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26455.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11599.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14450.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29720.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/841.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6156.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7331.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16333.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2094.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21033.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20054.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17805.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28912.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2374.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22146.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12916.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7036.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18889.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9257.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28403.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30211.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27059.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7722.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6985.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3218.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12233.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6696.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4575.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27880.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6056.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28997.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26637.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2843.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23878.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23167.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5049.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8812.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18986.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10075.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28696.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14378.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25965.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8404.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6604.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21838.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23288.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30384.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24520.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28922.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16994.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17529.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9846.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12201.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29892.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16825.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2919.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30409.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9061.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8642.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15124.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15212.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4307.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10672.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15598.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5933.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16313.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7172.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27792.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13129.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17311.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13974.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4641.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5556.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4383.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4272.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4134.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25314.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27133.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15241.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19400.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19062.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24919.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30160.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15900.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21835.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13325.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11679.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29307.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18824.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3689.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27020.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4008.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24387.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15125.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8341.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1971.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19450.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10544.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21785.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14445.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25459.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10551.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14478.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25126.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8330.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1606.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13249.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23987.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9919.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4030.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10445.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25869.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17179.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8046.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29410.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19931.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13322.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2630.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29960.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11319.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27551.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17816.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22536.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18164.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22565.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2265.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10480.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1244.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29716.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28407.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22622.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26234.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23731.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7087.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29405.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19265.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16607.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25940.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7869.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25880.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30493.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25597.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30370.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21143.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27892.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16648.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9986.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29076.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26535.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12526.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1561.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30125.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6057.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/31015.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21615.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28373.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8718.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7180.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3335.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3569.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30057.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26065.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23487.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/543.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27916.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21559.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21668.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26646.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26664.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29843.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24208.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30648.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14576.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27453.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28725.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6078.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5956.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25497.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20669.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13978.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4445.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24855.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2740.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5500.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/178.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19179.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14639.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12049.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4377.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7417.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29604.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22731.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5364.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6372.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14240.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28151.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29434.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19372.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29512.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1774.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21935.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8913.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23142.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16299.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1507.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4967.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1485.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6949.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18753.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27131.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16184.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27636.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10128.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15484.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29222.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29971.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8107.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25759.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4990.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25538.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18892.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24959.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16193.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20460.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18619.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10289.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10716.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2248.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6089.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2360.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27194.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/509.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16699.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15233.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12532.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9210.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28101.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26705.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22927.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6867.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19990.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19693.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14207.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15134.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15120.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30308.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25633.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14141.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7059.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10273.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29966.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5766.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26920.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11120.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30813.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8873.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1938.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19625.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13702.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11028.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5554.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13589.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8603.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24971.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24931.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1516.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26329.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17138.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/346.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22092.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15388.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13439.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29695.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12262.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/71.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17551.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/358.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20205.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13641.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20297.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4112.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29191.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30530.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15667.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5208.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27552.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19126.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10251.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8798.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14568.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17898.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2464.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26375.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4822.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23845.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22657.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13601.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6848.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13479.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24021.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27246.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30899.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20334.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6096.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13283.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2696.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21506.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28321.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7136.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5552.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11270.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22763.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18751.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16266.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16778.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12047.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25196.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7062.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3497.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24775.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14181.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27794.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9127.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21016.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13990.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2644.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28683.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17030.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13127.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17117.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10203.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7977.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10389.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6905.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16268.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20383.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20161.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28115.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4279.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7339.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23979.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11276.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18513.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28358.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12324.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8996.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25541.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26616.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13353.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/811.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19364.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4053.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17539.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28882.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30321.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11473.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3505.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21123.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/365.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11611.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26131.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12562.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28879.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/209.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26841.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18821.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18543.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13550.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6450.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4467.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2136.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13179.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20324.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23422.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14906.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17139.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7609.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16386.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17192.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6428.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4437.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1581.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9520.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25930.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4862.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6607.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23373.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17915.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11007.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11609.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15540.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26875.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30456.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9216.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6668.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11306.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12990.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/356.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26153.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14916.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8371.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19411.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12306.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17884.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3648.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24572.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8903.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8915.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13804.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15708.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15041.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17878.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1426.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28353.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8121.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16369.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23449.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14494.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7465.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21140.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6336.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/5984.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22537.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23777.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13660.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29872.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29472.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13140.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7699.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21112.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3642.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18368.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9479.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4946.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24076.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18349.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23358.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17377.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25134.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30157.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22692.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4549.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/19360.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4115.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10063.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25802.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/445.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2617.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24621.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24776.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24442.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9999.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/752.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16908.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17421.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2273.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3805.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8022.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26778.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13426.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18720.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22257.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14463.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14640.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12072.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15334.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8632.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7212.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16038.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24642.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9735.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26294.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18266.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28416.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16421.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2732.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20457.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15746.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22523.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10458.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25893.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13721.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23452.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18819.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1722.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11389.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29341.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/18485.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6550.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24937.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8732.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29218.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10932.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26098.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/6678.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/23379.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12399.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/3682.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4841.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12785.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14715.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27225.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24103.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/10914.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/20610.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27062.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12561.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12610.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12485.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12011.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7472.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7259.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26685.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27215.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/672.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24434.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26026.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28076.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28823.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17988.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25935.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/8781.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27699.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7762.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7807.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/13281.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/4079.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26814.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17399.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2040.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22128.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27733.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/21870.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/28682.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27557.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1781.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12618.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/9195.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/17974.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12656.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30135.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/15443.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/25546.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/566.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/14154.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/22584.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/1044.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/24179.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11806.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7011.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/7755.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/2176.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/11169.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/12174.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/27164.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/26423.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/30672.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/16417.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/train/29825.png
# ...
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/27291.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/17257.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25005.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/14959.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21763.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/27677.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5419.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5967.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25826.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24852.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/23223.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8383.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/4723.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2315.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2456.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2074.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16411.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/3286.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16546.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21066.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24024.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/983.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/27521.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/27266.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/17261.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24410.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21797.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28766.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/7873.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16248.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/13988.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/9307.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/17496.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5064.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25514.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12821.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12893.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10168.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/30594.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25716.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12870.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/18843.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/29642.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1780.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10660.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/19782.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/9822.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/3681.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5075.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/26857.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12359.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25713.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/20657.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1084.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/19170.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24015.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/20459.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/19048.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/23381.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/18163.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5510.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5653.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16074.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/14167.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12219.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21106.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8102.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/29152.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28731.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/3418.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24958.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/9422.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/4054.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/7471.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21477.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1522.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/18805.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21513.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/19448.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/30957.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21582.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10947.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/4782.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2721.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/9541.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8927.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/29206.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/29891.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16191.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24766.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16679.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/3572.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/11498.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/30026.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/6251.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/13539.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10882.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28036.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/18419.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/4449.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12846.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/22418.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/14593.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/19219.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12423.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/287.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8751.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/17183.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1446.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/14134.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2336.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/15556.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/6837.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/382.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/26029.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/23934.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/14879.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2453.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/27935.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/11596.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24294.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5193.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/3442.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/22238.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/15077.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/20958.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16023.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/15038.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16870.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5209.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1908.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/15015.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/9577.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/11624.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/18002.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/15972.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10388.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12939.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24137.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8579.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/4592.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/963.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/27805.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1159.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1338.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/4567.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/3421.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2042.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25420.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/26007.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1220.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/22019.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28381.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5355.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/7535.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8757.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/26724.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/11988.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10801.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/17290.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/29565.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/18367.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/26529.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/11014.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28460.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/11875.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/6647.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/18519.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/19224.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1285.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/9107.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1676.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/3451.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1390.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/12761.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/14824.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/15483.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28261.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28142.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28750.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8896.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/4056.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25734.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2425.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/15399.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/684.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/27816.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28807.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/14823.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/20340.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16997.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16776.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/22637.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10975.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/9445.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2641.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10400.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10425.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/17862.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/13422.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/31002.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/6094.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/24607.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/7303.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16857.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5307.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25163.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21098.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/10570.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/23465.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/13365.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16286.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/28881.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/6369.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/5532.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2298.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1619.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2332.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21836.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/26450.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/17964.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/2618.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/21875.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/1658.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/6637.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/19713.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/11115.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/20870.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/902.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/7110.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/16058.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/14064.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/25032.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8098.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/9530.png
# /kaggle/input/jovian-pytorch-z2g/Human protein atlas/test/8454.png

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import random
from PIL import Image
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, random_split, DataLoader

import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.utils import make_grid

# %% [markdown]
#  ## Exploring the Data
#
# When you create a notebook with the "Notebooks" tab of a Kaggle competition, the data is automatically included in the `../input` folder. You can explore the files in the sidebar. Let us create some constants acess the data directories and CSV files.

# %%
DATA_DIR = '../input/jovian-pytorch-z2g/Human protein atlas/'

TRAIN_DIR = DATA_DIR + "/" + "train"
TEST_DIR = DATA_DIR + "/" + "test"

TRAIN_CSV = DATA_DIR +"/" + "train.csv"
TEST_CSV = '../input/jovian-pytorch-z2g/submission.csv'

# %% [markdown]
# The `train.csv` file contains image IDs and labels for training data. Note that this is a multi-label classification problem. Each image can have more than one type of protein.

# %%
# !head "{TRAIN_CSV}"
# Out:
# Image,Label
# 19567,9
# 29993,6 4
# 17186,1 4
# 29600,6 2
# 701,3 4
# 26562,9
# 1080,4
# 27886,4
# 30721,6

# %%
# !head "{TEST_CSV}"
# Out:
# Image,Label
# 24117,0
# 15322,0
# 14546,0
# 8079,0
# 13192,0
# 25927,0
# 3372,0
# 21781,0
# 2847,0

# %% [markdown]
# Let's load the `train.csv` file into a Pandas dataframe

# %%
train_df = pd.read_csv(TRAIN_CSV)
train_df.head()
# Out:
#    Image Label
# 0  19567     9
# 1  29993   6 4
# 2  17186   1 4
# 3  29600   6 2
# 4    701   3 4

# %%
labels = {
    0: 'Mitochondria',
    1: 'Nuclear bodies',
    2: 'Nucleoli',
    3: 'Golgi apparatus',
    4: 'Nucleoplasm',
    5: 'Nucleoli fibrillar center',
    6: 'Cytosol',
    7: 'Plasma membrane',
    8: 'Centrosome',
    9: 'Nuclear speckles'
}

# %%
rev_labels = dict()
for key in labels.keys():
    rev_labels[labels[key]] = key

# %%
rev_labels
# Out:
# {'Mitochondria': 0,
#  'Nuclear bodies': 1,
#  'Nucleoli': 2,
#  'Golgi apparatus': 3,
#  'Nucleoplasm': 4,
#  'Nucleoli fibrillar center': 5,
#  'Cytosol': 6,
#  'Plasma membrane': 7,
#  'Centrosome': 8,
#  'Nuclear speckles': 9}

# %%
def num_to_name(labels):
    return [labels[i] for i in labels]

# %%
def name_to_num(labels):
    return [rev_labels[i] for i in labels]

# %%
def set_seed(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
set_seed(17)

# %%
def encode_labels(label):
    target = torch.zeros(10)
    for l in str(label).split(' '):
        target[int(l)] = 1.
    return target

# %%
def decode_labels(target, thresh=0.5, return_label=False):
    result = []
    for i, tgt in enumerate(target):
        if tgt > thresh:
            if return_label:
                result.append(str(i) + ":" + labels[i] + "/")
            else:
                result.append(str(i))
            
    return result

# %% [markdown]
# ### DISPLAY IMAGES

# %%
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
        return tensor

# %%
def display_img(img, label=None, unnorm=False, unnorm_obj=None, invert=True, return_label=True):
    if unnorm and unnorm_obj != None:
        img = unnorm_obj(img)
    
    if invert:
        plt.imshow(1 - img.permute((1, 2, 0)))
    else:
        plt.imshow(img.permute(1, 2, 0))
    
    if label != None:
        plt.title(decode_labels(label, return_label=return_label))

# %%
def display_batch(batch, unnorm=False, unnorm_obj=None, invert=True):    
    imgs, labels = batch
    
    if unnorm and unnorm_obj:
        unnorm_imgs = []
        for img in imgs:
            if invert:
                unnorm_imgs.append(1 - unnorm_obj(img))
            else:
                unnorm_imgs.append(unnorm_obj(img))
        imgs = unnorm_imgs
    else:
        if invert:
            imgs = 1 - imgs
    
    ig, ax = plt.subplots(figsize=(16, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(imgs, nrow=16).permute(1, 2, 0))

# %% [markdown]
# ### DATASET

# %%
class ProteinDataset(nn.Module):
    def __init__(self, root_dir, label_df, transforms=None):
        assert(os.path.exists(root_dir))
        self.root_dir = root_dir
        self.label_df = label_df
        self.transforms = transforms
        
    def __len__(self):
        return len(self.label_df)
    
    def __getitem__(self, idx):
        row = self.label_df.loc[idx]
        img_id, label = row['Image'], row['Label']
        img = Image.open(self.root_dir + "/" + str(img_id) + ".png")
        if self.transforms:
            img = self.transforms(img)
        return img, encode_labels(label)

# %%
mean = [0.0793, 0.0530, 0.0545]
std = [0.1290, 0.0886, 0.1376]

# %%
normalize = transforms.Normalize(mean=mean, std=std)

train_tf = transforms.Compose([
    transforms.RandomCrop(512, padding=8, padding_mode='symmetric'),
    transforms.RandomHorizontalFlip(), 
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    normalize,
    transforms.RandomErasing(inplace=True)
])

test_tf = transforms.Compose([
    transforms.RandomCrop(512, padding=8, padding_mode='symmetric'),
    transforms.ToTensor(),
    normalize
])

# %%
val_pct = 0.1

# %%
msk = np.random.rand(len(train_df)) < (1- val_pct)

# %%
train_split_df = train_df[msk].reset_index()
val_split_df = train_df[~msk].reset_index()

# %%
len(train_split_df), len(val_split_df)
# Out:
# (17444, 1792)

# %%
train_ds = ProteinDataset(TRAIN_DIR, train_split_df, train_tf)
valid_ds = ProteinDataset(TRAIN_DIR, val_split_df, test_tf)

# %%
bs = 32

# %%
train_loader = DataLoader(train_ds, bs, shuffle=True, num_workers=4, pin_memory=True)
valid_loader = DataLoader(valid_ds, bs, num_workers=4, pin_memory=True)

# %%
img, label = train_ds[1]

# %%
display_img(img, label)

# %%
unnorm = UnNormalize(mean, std)

# %%
display_img(img, label, unnorm=True, unnorm_obj=unnorm)

# %%
batch = next(iter(train_loader))

# %%
display_batch(batch)

# %% [markdown]
# ### F1 Score/Stats Function

# %%
def F_score(output, label, threshold=0.5, beta=1):
    prob = output > threshold
    label = label > threshold

    TP = (prob & label).sum(1).float()
    TN = ((~prob) & (~label)).sum(1).float()
    FP = (prob & (~label)).sum(1).float()
    FN = ((~prob) & label).sum(1).float()

    precision = torch.mean(TP / (TP + FP + 1e-15))
    recall = torch.mean(TP / (TP + FN + 1e-15))
    F2 = (1 + beta**2) * precision * recall / (beta**2 * precision + recall + 1e-15)
    return F2.mean(0)

# %%
class AvgStats(object):
    def __init__(self):
        self.reset()
        
    def reset(self):
        self.losses =[]
        self.F1 =[]
        self.its = []
        
    def append(self, loss, F1, it):
        self.losses.append(loss)
        self.F1.append(F1)
        self.its.append(it)

# %%
import math


class CLR(object):
    def __init__(self, optim, bn, base_lr=1e-7, max_lr=100):
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.optim = optim
        self.bn = bn - 1
        ratio = self.max_lr/self.base_lr
        self.mult = ratio ** (1/self.bn)
        self.best_loss = 1e9
        self.iteration = 0
        self.lrs = []
        self.losses = []
        
    def calc_lr(self, loss):
        self.iteration +=1
        if math.isnan(loss) or loss > 4 * self.best_loss:
            return -1
        if loss < self.best_loss and self.iteration > 1:
            self.best_loss = loss
            
        mult = self.mult ** self.iteration
        lr = self.base_lr * mult
        
        self.lrs.append(lr)
        self.losses.append(loss)
        
        return lr
        
    def plot(self, start=10, end=-5):
        plt.xlabel("Learning Rate")
        plt.ylabel("Losses")
        plt.plot(self.lrs[start:end], self.losses[start:end])
        plt.xscale('log')
        
        
    def plot_lr(self):
        plt.xlabel("Iterations")
        plt.ylabel("Learning Rate")
        plt.plot(self.lrs)
        plt.yscale('log')

# %%
class OneCycle(object):
    def __init__(self, nb, max_lr, momentum_vals=(0.95, 0.85), prcnt= 10, div=10, use_cosine=False):
        self.nb = nb
        self.div = div
        self.high_lr = max_lr
        self.low_mom = momentum_vals[1]
        self.high_mom = momentum_vals[0]
        self.use_cosine = use_cosine
        if self.use_cosine:
            self.prcnt = 0
        else:
            self.prcnt = prcnt
        self.iteration = 0
        self.lrs = []
        self.moms = []
        if self.use_cosine:
            self.step_len =  int(self.nb / 4)
        else:
            self.step_len =  int(self.nb * (1- prcnt/100)/2)
        
    def calc(self):
        if self.use_cosine:
            lr = self.calc_lr_cosine()
            mom = self.calc_mom_cosine()
        else:
            lr = self.calc_lr()
            mom = self.calc_mom()
        self.iteration += 1
        return (lr, mom)
        
    def calc_lr(self):
        if self.iteration ==  0:
            self.lrs.append(self.high_lr/self.div)
            return self.high_lr/self.div
        elif self.iteration == self.nb:
            self.iteration = 0
            self.lrs.append(self.high_lr/self.div)
            return self.high_lr/self.div
        elif self.iteration > 2 * self.step_len:
            ratio = (self.iteration - 2 * self.step_len) / (self.nb - 2 * self.step_len)
            #lr = self.high_lr * ( 1 - 0.99 * ratio)/self.div
            lr = (self.high_lr / self.div) * (1- ratio * (1 - 1/self.div))
        elif self.iteration > self.step_len:
            ratio = 1- (self.iteration -self.step_len)/self.step_len
            lr = self.high_lr * (1 + ratio * (self.div - 1)) / self.div
        else :
            ratio = self.iteration/self.step_len
            lr = self.high_lr * (1 + ratio * (self.div - 1)) / self.div
        self.lrs.append(lr)
        return lr

    def calc_mom(self):
        if self.iteration == 0:
            self.moms.append(self.high_mom)
            return self.high_mom
        elif self.iteration == self.nb:
            self.iteration = 0
            self.moms.append(self.high_mom)
            return self.high_mom
        elif self.iteration > 2 * self.step_len:
            mom = self.high_mom
        elif self.iteration > self.step_len:
            ratio = (self.iteration -self.step_len)/self.step_len
            mom = self.low_mom + ratio * (self.high_mom - self.low_mom)
        else :
            ratio = self.iteration/self.step_len
            mom = self.high_mom - ratio * (self.high_mom - self.low_mom)
        self.moms.append(mom)
        return mom

    def calc_lr_cosine(self):
        if self.iteration ==  0:
            self.lrs.append(self.high_lr/self.div)
            return self.high_lr/self.div
        elif self.iteration == self.nb:
            self.iteration = 0
            self.lrs.append(self.high_lr/self.div)
            return self.high_lr/self.div
        elif self.iteration > self.step_len:
            ratio = (self.iteration -self.step_len)/(self.nb - self.step_len)
            lr = (self.high_lr/self.div) + 0.5 * (self.high_lr - self.high_lr/self.div) * (1 + math.cos(math.pi * ratio))
        else :
            ratio = self.iteration/self.step_len
            lr = self.high_lr - 0.5 * (self.high_lr - self.high_lr/self.div) * (1 + math.cos(math.pi * ratio))
        self.lrs.append(lr)
        return lr

    def calc_mom_cosine(self):
        if self.iteration == 0:
            self.moms.append(self.high_mom)
            return self.high_mom
        elif self.iteration == self.nb:
            self.iteration = 0
            self.moms.append(self.high_mom)
            return self.high_mom
        elif self.iteration > self.step_len:
            ratio = (self.iteration -self.step_len)/(self.nb - self.step_len)
            mom = self.high_mom - 0.5 * (self.high_mom - self.low_mom) * (1 + math.cos(math.pi * ratio))
        else :
            ratio = self.iteration/self.step_len
            mom = self.low_mom + 0.5 * (self.high_mom - self.low_mom) * (1 + math.cos(math.pi * ratio))
        self.moms.append(mom)
        return mom

# %%
def save_checkpoint(model, is_best, filename='data/checkpoint.pth'):
    """Save checkpoint if a new best is achieved"""
    if is_best:
        torch.save(model.state_dict(), filename)  # save checkpoint
    else:
        print ("=> Validation Accuracy did not improve")

# %%
def load_checkpoint(model, filename = 'data/checkpoint.pth'):
    sd = torch.load(filename, map_location=lambda storage, loc: storage)
    names = set(model.state_dict().keys())
    for n in list(sd.keys()):
        if n not in names and n+'_raw' in names:
            if n+'_raw' not in sd: sd[n+'_raw'] = sd[n]
            del sd[n]
    model.load_state_dict(sd)

# %%
class AdaptiveConcatPool2d(nn.Module):
    def __init__(self, sz=1):
        super().__init__()
        self.adavgp = nn.AdaptiveAvgPool2d(sz)
        self.adamaxp = nn.AdaptiveMaxPool2d(sz)
        
    def forward(self, x):
        x = torch.cat([self.adavgp(x), self.adamaxp(x)], 1)
        x = x.view(x.size(0),-1)
        return x

# %%
class CustomClassifier(nn.Module):
    def __init__(self, in_features, intermed_bn= 512, out_features=10, dout=0.25):
        super().__init__()
        self.fc_bn0 = nn.BatchNorm1d(in_features)
        self.dropout0 = nn.Dropout(dout)
        self.fc0 = nn.Linear(in_features, intermed_bn, bias=True)
        self.fc_bn1 = nn.BatchNorm1d(intermed_bn, momentum=0.01)
        self.dropout1 = nn.Dropout(dout * 2)
        self.fc1 = nn.Linear(intermed_bn, out_features, bias=True)
        
    def forward(self, x):
        x = self.fc_bn0(x)
        x = self.dropout0(x)
        x = F.relu(self.fc0(x))
        x = self.fc_bn1(x)
        x = self.dropout1(x)
        x = self.fc1(x)
        return x

# %%
def update_lr(optimizer, lr):
    for g in optimizer.param_groups:
        g['lr'] = lr

# %%
def update_mom(optimizer, mom):
    for g in optimizer.param_groups:
        g['momentum'] = mom

# %%
def find_lr(model, loader, device):
    t = tqdm(loader, leave=False, total=len(loader))
    running_loss = 0.
    avg_beta = 0.98
    model.train()
    for i, (ip, tgt) in enumerate(t):
        ip, tgt = ip.to(device), tgt.to(device)
        output = torch.sigmoid(model(ip))
        loss = criterion(output, tgt)

        running_loss = avg_beta * running_loss + (1-avg_beta) *loss.item()
        smoothed_loss = running_loss / (1 - avg_beta**(i+1))
        t.set_postfix(loss=smoothed_loss)

        lr = clr.calc_lr(smoothed_loss)
        if lr == -1 :
            break
        update_lr(optimizer, lr)   

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
model = models.resnet34(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
model.avgpool = AdaptiveConcatPool2d()
model.fc = CustomClassifier(in_features=model.fc.in_features*2, out_features=10)

# %%
for param in model.parameters():
    param.require_grad = True
    
model = model.to(device)

# %%
criterion = nn.BCELoss()

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9, weight_decay=1e-4)

# %%
save_checkpoint(model, True, 'init.pth')

# %%
clr = CLR(optimizer, len(train_loader))

# %%
find_lr(model, train_loader, device)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))

# %%
clr.plot()

# %%
def train(epoch, model, optimizer, use_cycle=False, onecycle=None):
    model.train()
    global trn_F1, trn_losses, trn_time
    running_loss = 0.
    running_F1 = 0.
    
    start_time = time.time()
    
    t = tqdm(train_loader, leave=False, total=len(train_loader))

    for i, (ip, tgt) in enumerate(t):
        ip, tgt = ip.to(device), tgt.to(device)
        
        if use_cycle:    
            lr, mom = onecycle.calc()
            update_lr(optimizer, lr)
            update_mom(optimizer, mom)
                                    
        output = torch.sigmoid(model(ip))
        loss = criterion(output, tgt)
        running_loss += loss.item()
            
        # Append outputs
        running_F1 += F_score(tgt, output)
        
        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    trn_time = time.time() - start_time        
    trn_F1 = running_F1/len(train_loader)
    trn_losses = running_loss/len(train_loader)

# %%
def test(model):
    with torch.no_grad():
        model.eval()
        global best_F1
        global val_F1, val_losses, val_time
        running_loss = 0.
        running_F1 = 0.
        start_time = time.time()
        
        t = tqdm(valid_loader, leave=False, total=len(valid_loader))
        
        for i, (ip, tgt) in enumerate(t):
            ip, tgt = ip.to(device), tgt.to(device)
            output = torch.sigmoid(model(ip))
            loss = criterion(output, tgt)
            running_loss += loss.item()
            running_F1 += F_score(tgt, output)
            
        val_time = time.time() - start_time
        F1_score = running_F1/len(valid_loader)
        if F1_score > best_F1:
            best_F1 = F1_score
            save_checkpoint(model, True, './best_model.pth')
            
        val_F1 = F1_score
        val_losses = running_loss/len(valid_loader)

# %%
train_stats = AvgStats()
test_stats = AvgStats()

# %%
best_F1 = 0
trn_time = 0
trn_losses = 0.0
trn_F1 = 0.0
val_losses = 0.0
val_F1 = 0.0
val_time = 0

# %%
def fit(model, optimizer, epochs, sched=None, use_cycle=False, onecycle=None):
    print("Epoch\tTrn_loss\tVal_loss\tTrn_F1\t\tVal_F1")
    for j in range(epochs):
        train(j, model, optimizer, use_cycle=use_cycle, onecycle=onecycle)
        train_stats.append(trn_losses, trn_F1, trn_time)
        test(model)
        test_stats.append(val_losses, val_F1, val_time)
        if sched:
            sched.step(j)
        print("{}\t{:06.8f}\t{:06.8f}\t{:06.8f}\t{:06.8f}"
              .format(j+1, trn_losses, val_losses, trn_F1, val_F1))

# %%
epochs = 15

# %%
load_checkpoint(model, 'init.pth')

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9, weight_decay=1e-4)

# %%
ocp = OneCycle(int(len(train_ds) * epochs /bs), 1e-1, use_cosine=True)

# %%
import time

# %%
fit(model, optimizer, epochs, use_cycle=True, onecycle=ocp)
# Out:
# Epoch	Trn_loss	Val_loss	Trn_F1		Val_F1
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 1	0.36741001	0.25950345	0.49771816	0.58995134
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 2	0.26018098	0.26673441	0.62216705	0.59165412
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 3	0.24434600	0.22388746	0.65551054	0.67512637
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 4	0.23033157	0.23661960	0.68472248	0.70496041
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 5	0.21788720	0.24000172	0.70127046	0.60855246
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 6	0.20737249	0.20519083	0.71469915	0.73342103
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 7	0.19884121	0.21606863	0.73026621	0.68826264
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 8	0.19351969	0.20674446	0.73904467	0.67342114
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 9	0.18576869	0.19277268	0.74921513	0.73588145
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 10	0.18059393	0.18655622	0.75690293	0.71549535
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 11	0.17328705	0.17783332	0.76757979	0.76270121
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 12	0.16635067	0.17842152	0.78339899	0.77157050
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 13	0.16001507	0.16169139	0.79312980	0.78886181
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 14	0.15194932	0.15832887	0.80506605	0.79764187
# HBox(children=(FloatProgress(value=0.0, max=546.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=56.0), HTML(value='')))
# 15	0.14269285	0.16058432	0.81736082	0.79416776

# %%
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.plot(train_stats.losses, 'r', label='train')
plt.plot(test_stats.losses, 'g', label='valid')
plt.legend()
plt.show()

# %%
plt.xlabel("Epochs")
plt.ylabel("F1-score")
plt.plot(train_stats.F1, 'r', label='train')
plt.plot(test_stats.F1, 'g', label='valid')
plt.legend()
plt.show()

# %%
def pred_single(img, return_label=True):
    with torch.no_grad():
        model.eval()
        bs_img = img.unsqueeze(0)
        bs_img = bs_img.to(device)
        preds = torch.sigmoid(model(bs_img))
        prediction = preds[0]
        display_img(img, prediction, return_label)

# %%
test_df = pd.read_csv(TEST_CSV)

# %%
test_ds = ProteinDataset(TEST_DIR, test_df, test_tf)

# %%
img, label = test_ds[100]

# %%
pred_single(img)

# %%
test_loader = DataLoader(test_ds, bs, num_workers=4, pin_memory=True)

# %%
load_checkpoint(model, './best_model.pth')

# %%
def predict(loader):
    with torch.no_grad():
        torch.cuda.empty_cache()
        model.eval()
        preds = []
        t = tqdm(loader, leave=False, total=len(loader))
        for i, (ip, _) in enumerate(t):
            ip = ip.to(device)
            output = torch.sigmoid(model(ip))
            preds.append(output.cpu().detach())
        preds = torch.cat(preds)
        return [" ".join(decode_labels(pred)) for pred in preds]

# %%
preds = predict(test_loader)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=258.0), HTML(value='')))

# %%
len(preds), len(test_df)
# Out:
# (8243, 8243)

# %%
preds
# Out:
# ['4 8 9',
#  '4',
#  '6',
#  '3 6',
#  '3 4',
#  '1',
#  '0',
#  '3 6',
#  '4',
#  '9',
#  '9',
#  '4 7',
#  '3 4',
#  '7',
#  '3 4',
#  '5',
#  '1',
#  '4 8',
#  '9',
#  '4 7',
#  '2 4',
#  '4',
#  '7',
#  '4 5 6 7',
#  '4 6',
#  '4 7',
#  '4 7',
#  '4 6',
#  '1',
#  '5 6',
#  '4',
#  '4',
#  '4 6 7',
#  '3 4',
#  '0',
#  '4',
#  '7',
#  '4',
#  '6',
#  '4 6',
#  '4',
#  '1',
#  '3',
#  '6',
#  '4 6',
#  '4 7',
#  '2 7',
#  '4',
#  '0',
#  '3',
#  '6',
#  '2',
#  '9',
#  '4 7',
#  '0',
#  '4',
#  '4',
#  '6',
#  '9',
#  '1 4',
#  '2 4',
#  '6',
#  '0',
#  '3 4',
#  '2 4 6',
#  '5',
#  '3 5',
#  '0',
#  '0 4',
#  '6 7',
#  '9',
#  '',
#  '8',
#  '0 4',
#  '0 3',
#  '4',
#  '2 4',
#  '4',
#  '4 6',
#  '5',
#  '',
#  '4 6',
#  '4 6',
#  '2 4',
#  '9',
#  '3',
#  '2',
#  '2',
#  '2 4',
#  '4',
#  '3',
#  '1',
#  '5',
#  '4 6',
#  '2 3',
#  '0',
#  '4',
#  '4',
#  '6',
#  '1',
#  '4 6',
#  '8',
#  '6 9',
#  '7',
#  '4',
#  '4',
#  '2 4',
#  '1 6',
#  '0',
#  '2 3',
#  '3',
#  '6 7',
#  '',
#  '4',
#  '0',
#  '9',
#  '4',
#  '1',
#  '0',
#  '4',
#  '3',
#  '6 7',
#  '9',
#  '4 6',
#  '3',
#  '',
#  '4 6',
#  '6',
#  '0',
#  '9',
#  '2',
#  '2',
#  '0',
#  '7',
#  '0',
#  '4 6',
#  '3 4',
#  '2',
#  '0',
#  '0',
#  '1 6',
#  '4',
#  '0 4',
#  '2',
#  '2',
#  '8',
#  '4',
#  '4',
#  '3 6',
#  '9',
#  '4 6',
#  '3',
#  '4 6',
#  '1',
#  '4',
#  '9',
#  '4 6',
#  '4 6',
#  '2',
#  '0 2',
#  '1',
#  '6',
#  '1 4',
#  '1',
#  '0',
#  '3 5',
#  '6 7',
#  '1 4',
#  '2 4',
#  '4',
#  '0 2',
#  '8',
#  '4',
#  '6 7',
#  '2',
#  '4',
#  '6',
#  '9',
#  '3 6',
#  '7',
#  '4 5 6',
#  '6 9',
#  '6',
#  '6 7',
#  '4 6',
#  '0',
#  '3',
#  '0',
#  '6',
#  '9',
#  '7',
#  '4 8',
#  '4 8',
#  '',
#  '0',
#  '4',
#  '3 4',
#  '2',
#  '4 6 7',
#  '4 6 7',
#  '0',
#  '6',
#  '2',
#  '7',
#  '6',
#  '1',
#  '0',
#  '7',
#  '2 3',
#  '3',
#  '4',
#  '0 4',
#  '0',
#  '3 4',
#  '4',
#  '4 5 6',
#  '1',
#  '4',
#  '4',
#  '2 4',
#  '6',
#  '4',
#  '8',
#  '9',
#  '4',
#  '6',
#  '',
#  '8',
#  '2',
#  '0 4',
#  '4 6',
#  '1',
#  '9',
#  '3',
#  '4',
#  '9',
#  '7',
#  '3',
#  '2',
#  '3',
#  '0 4',
#  '4',
#  '2 4',
#  '4',
#  '2 4 6',
#  '4',
#  '2 4',
#  '1',
#  '6 9',
#  '2 4',
#  '6 9',
#  '9',
#  '2 4 6',
#  '',
#  '9',
#  '6',
#  '2 4 7',
#  '4',
#  '4',
#  '2',
#  '2 4',
#  '6',
#  '6',
#  '1',
#  '0',
#  '4',
#  '4',
#  '2 4',
#  '2 4',
#  '9',
#  '9',
#  '4 9',
#  '4',
#  '5 6',
#  '4 6',
#  '6',
#  '4 6',
#  '6',
#  '4',
#  '0',
#  '3 4',
#  '0',
#  '6',
#  '3',
#  '1 3',
#  '7',
#  '4 8',
#  '0 4',
#  '3 4',
#  '',
#  '3 4',
#  '4',
#  '7',
#  '0',
#  '4 5',
#  '6',
#  '2 6',
#  '4',
#  '2 7',
#  '4',
#  '6',
#  '7 9',
#  '6',
#  '0',
#  '2 4',
#  '1',
#  '3',
#  '9',
#  '6',
#  '4 9',
#  '2 6',
#  '9',
#  '9',
#  '0',
#  '9',
#  '2',
#  '4',
#  '6 8',
#  '4',
#  '4 6 8',
#  '0 2',
#  '0',
#  '6',
#  '0',
#  '4',
#  '0',
#  '3 9',
#  '3',
#  '2',
#  '6',
#  '4',
#  '2 4',
#  '0',
#  '6',
#  '2 7',
#  '4 5',
#  '4',
#  '4 6',
#  '6',
#  '2 4',
#  '9',
#  '4 8',
#  '0',
#  '7',
#  '2 3',
#  '2 4',
#  '1',
#  '0 4',
#  '3 4',
#  '5 6',
#  '2 6',
#  '0 9',
#  '1',
#  '2',
#  '3 4',
#  '4 5',
#  '1 4',
#  '',
#  '4 6',
#  '4',
#  '4',
#  '4',
#  '6 8',
#  '4',
#  '2 4',
#  '2 4',
#  '4',
#  '1 4',
#  '3',
#  '0 4',
#  '6',
#  '4',
#  '6 7',
#  '1 6',
#  '0 4',
#  '6',
#  '3 4',
#  '2',
#  '4 6',
#  '6',
#  '2',
#  '2 4',
#  '4',
#  '4 6',
#  '7',
#  '',
#  '1 4',
#  '4 6',
#  '2 6',
#  '6',
#  '6',
#  '4',
#  '0',
#  '6',
#  '1 4',
#  '',
#  '1',
#  '',
#  '1 6',
#  '4',
#  '0',
#  '3',
#  '4',
#  '4',
#  '2 4',
#  '3',
#  '2 4 7',
#  '2 4',
#  '4 6',
#  '4',
#  '2',
#  '2 4',
#  '6',
#  '4 7',
#  '4 6',
#  '4 8',
#  '2 4',
#  '6',
#  '0',
#  '4 7',
#  '7',
#  '2',
#  '8',
#  '3',
#  '9',
#  '4',
#  '2 4',
#  '6',
#  '4',
#  '9',
#  '0',
#  '2 4',
#  '1',
#  '6 9',
#  '4 6',
#  '4',
#  '0',
#  '9',
#  '3',
#  '2',
#  '2',
#  '0',
#  '',
#  '3 6',
#  '4 6',
#  '',
#  '9',
#  '3 6',
#  '7',
#  '4',
#  '4 6',
#  '4 6',
#  '1',
#  '2',
#  '4 6',
#  '0 4',
#  '9',
#  '4',
#  '9',
#  '4 5',
#  '4 6',
#  '5 6',
#  '0 4',
#  '4',
#  '3 4',
#  '9',
#  '4',
#  '6',
#  '0',
#  '2 4',
#  '8',
#  '4 6',
#  '4 6',
#  '0',
#  '1',
#  '2',
#  '3 4',
#  '1 4',
#  '4',
#  '9',
#  '0',
#  '4 6',
#  '4',
#  '4',
#  '9',
#  '4 6 7',
#  '2 4',
#  '3',
#  '3 4',
#  '0',
#  '2',
#  '0',
#  '0',
#  '7',
#  '4 6',
#  '4 6',
#  '7',
#  '2 4',
#  '2 4',
#  '7',
#  '4',
#  '4',
#  '6',
#  '8',
#  '2 4',
#  '4',
#  '0',
#  '2 4',
#  '4',
#  '3 4',
#  '0',
#  '3 4',
#  '3',
#  '4 6',
#  '4 5',
#  '0 2 4',
#  '3',
#  '0',
#  '7',
#  '6',
#  '2',
#  '4 6',
#  '6 7',
#  '3',
#  '6',
#  '3',
#  '3',
#  '4',
#  '1',
#  '4 6',
#  '0',
#  '6',
#  '4',
#  '5',
#  '2 6',
#  '4 6',
#  '4 6',
#  '2 4',
#  '1 4',
#  '2',
#  '4 6',
#  '1 4 6',
#  '',
#  '',
#  '6',
#  '1 4 6',
#  '9',
#  '9',
#  '4',
#  '0 4',
#  '4 6 7',
#  '8',
#  '2',
#  '7',
#  '6',
#  '1',
#  '5',
#  '4',
#  '2 4',
#  '4 6',
#  '4',
#  '4',
#  '7',
#  '2 7',
#  '4 7',
#  '7',
#  '4 6',
#  '7',
#  '4 6',
#  '3',
#  '',
#  '0',
#  '4',
#  '4 6',
#  '2',
#  '2 6',
#  '7 9',
#  '6',
#  '4',
#  '7',
#  '1',
#  '0',
#  '6 7',
#  '7',
#  '4 6',
#  '4',
#  '4',
#  '4',
#  '3',
#  '4 6',
#  '8',
#  '4',
#  '3',
#  '6',
#  '7',
#  '9',
#  '9',
#  '4 6',
#  '7',
#  '4',
#  '0',
#  '7',
#  '4 6',
#  '2 4',
#  '9',
#  '6',
#  '3',
#  '4 7',
#  '3 6 7',
#  '2 4',
#  '4 6',
#  '6',
#  '6 7',
#  '9',
#  '4',
#  '6 8',
#  '4 7',
#  '7',
#  '2 4 6',
#  '3',
#  '4',
#  '0',
#  '4',
#  '7',
#  '9',
#  '4 7',
#  '6',
#  '4 7',
#  '0 4',
#  '4 6',
#  '7',
#  '2 4',
#  '4',
#  '0',
#  '0',
#  '6',
#  '9',
#  '2 4 7',
#  '1',
#  '3',
#  '1 4',
#  '1',
#  '6',
#  '0',
#  '8',
#  '0',
#  '5 6',
#  '',
#  '8',
#  '3 4',
#  '3',
#  '4 6',
#  '4',
#  '3 4',
#  '2 4',
#  '3 4',
#  '9',
#  '4',
#  '9',
#  '7',
#  '0 2 4',
#  '2',
#  '0 4',
#  '4 6',
#  '6',
#  '0',
#  '1',
#  '4',
#  '8',
#  '4 5',
#  '6',
#  '9',
#  '9',
#  '4 6 7',
#  '6',
#  '5 6',
#  '4',
#  '7',
#  '2 4',
#  '6',
#  '4',
#  '2 4',
#  '4 6',
#  '4',
#  '2',
#  '',
#  '0',
#  '3 6',
#  '7',
#  '0 2',
#  '4 5',
#  '',
#  '4 6',
#  '3',
#  '2 4 6',
#  '',
#  '2',
#  '4 6',
#  '3',
#  '2',
#  '6 7',
#  '4 7',
#  '4',
#  '5',
#  '3',
#  '4',
#  '',
#  '2 4',
#  '4 5 6',
#  '3',
#  '7',
#  '1',
#  '6',
#  '7',
#  '4 6',
#  '6',
#  '2 4 7',
#  '7',
#  '6',
#  '1 7',
#  '5',
#  '0',
#  '4 6',
#  '5 6',
#  '7',
#  '5',
#  '7',
#  '4 8',
#  '2',
#  '0',
#  '9',
#  '4 5 8',
#  '4',
#  '4',
#  '0',
#  '7',
#  '4 6',
#  '9',
#  '5',
#  '0',
#  '6',
#  '6',
#  '9',
#  '4',
#  '9',
#  '0',
#  '4 6',
#  '1',
#  '6',
#  '4 6',
#  '4',
#  '3',
#  '4 6',
#  '',
#  '4 6',
#  '9',
#  '4',
#  '4',
#  '4 6 7',
#  '2',
#  '2',
#  '4 6',
#  '9',
#  '7',
#  '4',
#  '6',
#  '4',
#  '4 6',
#  '4',
#  '4',
#  '2 4',
#  '2 6',
#  '3',
#  '0',
#  '4',
#  '4',
#  '3',
#  '4',
#  '4',
#  '',
#  '6',
#  '4 7',
#  '6',
#  '4 7',
#  '2 6',
#  '',
#  '2',
#  '7',
#  '4 6',
#  '2 4',
#  '6',
#  '4 5 6',
#  '4',
#  '6',
#  '4',
#  '4',
#  '6 9',
#  '4 8',
#  '2',
#  '3 4',
#  '2',
#  '2 4',
#  '0 4',
#  '2 4 7',
#  '2',
#  '9',
#  '4 6',
#  '4 7',
#  '0',
#  '4 6 7',
#  '6',
#  '1 4 6',
#  '4 8',
#  '4',
#  '4 9',
#  '0',
#  '4 6',
#  '0',
#  '0',
#  '4',
#  '0',
#  '6 9',
#  '0',
#  '4',
#  '3',
#  '4 6',
#  '0',
#  '2',
#  '4',
#  '2 4',
#  '3',
#  '4 7',
#  '7',
#  '4',
#  '7',
#  '6 7',
#  '4',
#  '2 4',
#  '0',
#  '2',
#  '3 4',
#  '6',
#  '1',
#  '2',
#  '1 4',
#  '4 6',
#  '3',
#  '0',
#  '4 7',
#  '6',
#  '2 4',
#  '',
#  '2 6',
#  '4',
#  '7',
#  '6',
#  '4 6',
#  '3',
#  '4',
#  '1',
#  '3',
#  '4',
#  '',
#  '6',
#  '4 5',
#  '0',
#  '4',
#  '7',
#  '2 4',
#  '4 6',
#  '5',
#  '4 8',
#  '5',
#  '7',
#  '2 6',
#  '3',
#  '9',
#  '3',
#  '',
#  '2 4 6',
#  '7',
#  '1',
#  '0',
#  '4 6',
#  '4',
#  '2 4',
#  '3 4',
#  '4',
#  '6',
#  '3 4',
#  '4',
#  '6',
#  '5',
#  '3',
#  '6',
#  '2 4',
#  '6',
#  '7',
#  '4 6 7',
#  '4',
#  '0',
#  '4 6',
#  '2 6',
#  '4',
#  '3',
#  '0',
#  '4 6',
#  '2 4',
#  '4',
#  '0 3 4',
#  '7',
#  '0',
#  '9',
#  '4 6',
#  '1',
#  '4 6',
#  '4 6',
#  '4',
#  '6',
#  '6',
#  '3',
#  '5 6',
#  '1',
#  '6',
#  '2 4 7 8',
#  '4 6',
#  '9',
#  '2',
#  '3',
#  '0',
#  '4',
#  '5 6',
#  '4 6',
#  '6',
#  '0',
#  '3',
#  '2 4 7',
#  '5',
#  '4 6',
#  '6 7',
#  '',
#  '9',
#  '4 6',
#  '4 5',
#  '0',
#  '2 6',
#  '4 7',
#  '4 6',
#  '4 6 7',
#  '9',
#  '1 4',
#  '',
#  '3',
#  '3',
#  '6',
#  '8',
#  '4 8',
#  '9',
#  '4',
#  '3',
#  '4 6',
#  '2 4 7',
#  '4 8',
#  '6',
#  '3 4',
#  '9',
#  '2',
#  '9',
#  '4 7',
#  '4 9',
#  '4 6',
#  '9',
#  '4 7',
#  '4 5',
#  '4 6',
#  '4',
#  '6 7',
#  '4 6',
#  '4 6',
#  '4',
#  '0 6',
#  '9',
#  '7',
#  '9',
#  '4 7',
#  '2',
#  '2',
#  '1',
#  '4',
#  '2 4',
#  '6',
#  '7',
#  '4 6',
#  '7',
#  '4',
#  '4',
#  '5',
#  '9',
#  '3',
#  '4 7',
#  ...]

# %%
sub_df = pd.read_csv(TEST_CSV)

# %%
sub_df.head()
# Out:
#    Image  Label
# 0  24117      0
# 1  15322      0
# 2  14546      0
# 3   8079      0
# 4  13192      0

# %%
sub_df['Label'] = preds

# %%
sub_df.head()
# Out:
#    Image  Label
# 0  24117  4 8 9
# 1  15322      4
# 2  14546      6
# 3   8079    3 6
# 4  13192    3 4

# %%
sub_df.to_csv('submission.csv', index=False)

# %%
# !pip install jovian --upgrade
# Out:
# Collecting jovian
#   Downloading jovian-0.2.16-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.2 MB/s eta 0:00:011
# Requirement already satisfied, skipping upgrade: pyyaml in /opt/conda/lib/python3.7/site-packages (from jovian) (5.3.1)
# Requirement already satisfied, skipping upgrade: click in /opt/conda/lib/python3.7/site-packages (from jovian) (7.1.1)
# Requirement already satisfied, skipping upgrade: requests in /opt/conda/lib/python3.7/site-packages (from jovian) (2.23.0)
# Collecting uuid
#   Downloading uuid-1.30.tar.gz (5.8 kB)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->jovian) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->jovian) (2.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->jovian) (2020.4.5.2)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->jovian) (1.24.3)
# Building wheels for collected packages: uuid
#   Building wheel for uuid (setup.py) ... done
#   Created wheel for uuid: filename=uuid-1.30-py3-none-any.whl size=6500 sha256=ce3b609d0b5db055e59fcb50793e162d3001781000bc69c30922b97aa8866283
#   Stored in directory: /root/.cache/pip/wheels/2a/ea/87/dd57f1ecb4f0752f3e1dbf958ebf8b36d920d190425bcdc24d
# Successfully built uuid
# Installing collected packages: uuid, jovian
# Successfully installed jovian-0.2.16 uuid-1.30

# %%
import jovian

# %%
jovian.commit(project='zerogans-protein-competition')
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Detected Kaggle notebook...
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY: ········
# [jovian] Uploading notebook to https://jovian.ml/ritikdhedia46/zerogans-protein-competition
